# %% [markdown]
# # Account Information

# %%
# initialize ezIBAsync
from ezib_async.ezib import ezIBAsync
from ezib_async import util

# %%
util.logToConsole("INFO")

# %%
ezib = ezIBAsync()
await ezib.connectAsync(ibport=4002) # paper or live account
# Out:
# 2025-05-14 23:13:18,010 ezib_async.ezib INFO Connecting to IB at 127.0.0.1:4002 (client ID: 1)
# 2025-05-14 23:13:18,011 ib_async.client INFO Connecting to 127.0.0.1:4002 with clientId 1...
# 2025-05-14 23:13:18,013 ib_async.client INFO Connected
# 2025-05-14 23:13:18,069 ib_async.client INFO Logged on to server version 178
# 2025-05-14 23:13:18,225 ib_async.client INFO API connection ready
# 2025-05-14 23:13:18,230 ib_async.wrapper INFO Warning 2104, reqId -1: Market data farm connection is OK:hfarm
# 2025-05-14 23:13:18,234 ib_async.wrapper INFO Warning 2107, reqId -1: HMDS data farm connection is inactive but should be available upon demand.apachmds
# 2025-05-14 23:13:18,236 ib_async.wrapper INFO Warning 2158, reqId -1: Sec-def data farm connection is OK:secdefhk
# ...

# %%
# Multi-account Values
ezib.accounts
# Out:
# {'DU1200464': [AccountValue(account='DU1200464', tag='AccountCode', value='DU1200464', currency='', modelCode=''),
#   AccountValue(account='DU1200464', tag='AccountOrGroup', value='DU1200464', currency='BASE', modelCode=''),
#   AccountValue(account='DU1200464', tag='AccountOrGroup', value='DU1200464', currency='USD', modelCode=''),
#   AccountValue(account='DU1200464', tag='AccountReady', value='true', currency='', modelCode=''),
#   AccountValue(account='DU1200464', tag='AccountType', value='INDIVIDUAL', currency='', modelCode=''),
#   AccountValue(account='DU1200464', tag='AccruedCash', value='660.44', currency='BASE', modelCode=''),
#   AccountValue(account='DU1200464', tag='AccruedCash', value='660.44', currency='USD', modelCode=''),
#   AccountValue(account='DU1200464', tag='AccruedCash-C', value='0.00', currency='USD', modelCode=''),
#   AccountValue(account='DU1200464', tag='AccruedCash-P', value='0.00', currency='USD', modelCode=''),
# ...

# %%
# Active account Values
ezib.account
# Out:
# [AccountValue(account='DU1200464', tag='AccountCode', value='DU1200464', currency='', modelCode=''),
#  AccountValue(account='DU1200464', tag='AccountOrGroup', value='DU1200464', currency='BASE', modelCode=''),
#  AccountValue(account='DU1200464', tag='AccountOrGroup', value='DU1200464', currency='USD', modelCode=''),
#  AccountValue(account='DU1200464', tag='AccountReady', value='true', currency='', modelCode=''),
#  AccountValue(account='DU1200464', tag='AccountType', value='INDIVIDUAL', currency='', modelCode=''),
#  AccountValue(account='DU1200464', tag='AccruedCash', value='660.44', currency='BASE', modelCode=''),
#  AccountValue(account='DU1200464', tag='AccruedCash', value='660.44', currency='USD', modelCode=''),
#  AccountValue(account='DU1200464', tag='AccruedCash-C', value='0.00', currency='USD', modelCode=''),
#  AccountValue(account='DU1200464', tag='AccruedCash-P', value='0.00', currency='USD', modelCode=''),
# ...

# %%
# Multi-account Positions
ezib.positions
# Out:
# {'DU1200464': {'GLD': Position(account='DU1200464', contract=Stock(conId=51529211, symbol='GLD', exchange='ARCA', primaryExchange='ARCA', currency='USD', localSymbol='GLD', tradingClass='GLD'), position=100.0, avgCost=307.526738),
#   'ESM2025_FUT': Position(account='DU1200464', contract=Future(conId=620731015, symbol='ES', lastTradeDateOrContractMonth='20250620', multiplier='50', exchange='CME', currency='USD', localSymbol='ESM5', tradingClass='ES'), position=2.0, avgCost=285577.25),
#   'NVDA': Position(account='DU1200464', contract=Stock(conId=4815747, symbol='NVDA', exchange='NASDAQ', primaryExchange='NASDAQ', currency='USD', localSymbol='NVDA', tradingClass='NMS'), position=100.0, avgCost=118.303749)}}

# %%
# Active account Positions
ezib.position
# Out:
# {'GLD': Position(account='DU1200464', contract=Stock(conId=51529211, symbol='GLD', exchange='ARCA', primaryExchange='ARCA', currency='USD', localSymbol='GLD', tradingClass='GLD'), position=100.0, avgCost=307.526738),
#  'ESM2025_FUT': Position(account='DU1200464', contract=Future(conId=620731015, symbol='ES', lastTradeDateOrContractMonth='20250620', multiplier='50', exchange='CME', currency='USD', localSymbol='ESM5', tradingClass='ES'), position=2.0, avgCost=285577.25),
#  'NVDA': Position(account='DU1200464', contract=Stock(conId=4815747, symbol='NVDA', exchange='NASDAQ', primaryExchange='NASDAQ', currency='USD', localSymbol='NVDA', tradingClass='NMS'), position=100.0, avgCost=118.303749)}

# %%
# Multi-account Portfolios
ezib.portfolios
# Out:
# {'DU1200464': {'ESM2025_FUT': PortfolioItem(contract=Future(conId=620731015, symbol='ES', lastTradeDateOrContractMonth='20250620', right='0', multiplier='50', primaryExchange='CME', currency='USD', localSymbol='ESM5', tradingClass='ES'), position=2.0, marketPrice=5902.0, marketValue=590200.0, averageCost=285577.25, unrealizedPNL=19045.5, realizedPNL=0.0, account='DU1200464'),
#   'GLD': PortfolioItem(contract=Stock(conId=51529211, symbol='GLD', right='0', primaryExchange='ARCA', currency='USD', localSymbol='GLD', tradingClass='GLD'), position=100.0, marketPrice=293.04599, marketValue=29304.6, averageCost=307.526738, unrealizedPNL=-1448.07, realizedPNL=0.0, account='DU1200464'),
# ...

# %%
# Active account Portfolios
ezib.portfolio
# Out:
# {'ESM2025_FUT': PortfolioItem(contract=Future(conId=620731015, symbol='ES', lastTradeDateOrContractMonth='20250620', right='0', multiplier='50', primaryExchange='CME', currency='USD', localSymbol='ESM5', tradingClass='ES'), position=2.0, marketPrice=5902.0, marketValue=590200.0, averageCost=285577.25, unrealizedPNL=19045.5, realizedPNL=0.0, account='DU1200464'),
#  'GLD': PortfolioItem(contract=Stock(conId=51529211, symbol='GLD', right='0', primaryExchange='ARCA', currency='USD', localSymbol='GLD', tradingClass='GLD'), position=100.0, marketPrice=293.04599, marketValue=29304.6, averageCost=307.526738, unrealizedPNL=-1448.07, realizedPNL=0.0, account='DU1200464'),
#  'NVDA': PortfolioItem(contract=Stock(conId=4815747, symbol='NVDA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='NVDA', tradingClass='NMS'), position=100.0, marketPrice=133.8899994, marketValue=13389.0, averageCost=118.303749, unrealizedPNL=1558.63, realizedPNL=0.0, account='DU1200464')}

# %%
# disconnect
ezib.disconnect()
# Out:
# 2025-05-14 23:13:39,925 ezib_async.ezib INFO Disconnecting from IB
# 2025-05-14 23:13:39,931 ib_async.ib INFO Disconnecting from 127.0.0.1:4002, 538 B sent in 16 messages, 24.9 kB received in 407 messages, session time 21.9 s.
# 2025-05-14 23:13:39,931 ib_async.client INFO Disconnecting
# 2025-05-14 23:13:39,932 ezib_async.ezib INFO Disconnected.
# 2025-05-14 23:13:39,938 ib_async.client INFO Disconnected.
